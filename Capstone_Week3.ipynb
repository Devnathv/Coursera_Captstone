# %% [markdown]
# # Importing Libraries for the Porject

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# *Use the Requests and Beautiful soup packages for webscraping data*

# %%
website_url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
soup=BeautifulSoup(website_url,'lxml')

# %%
My_table=soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# ## Data transformation steps
# 1. Assign columns to the empty dataframe
# 2. Peform various clean up operations on the dataframe
#     * Remove Boroughs not assigned
#     * Assign Neighbourhoods that are not assigned with those of Boroughs

# %%
df=pd.DataFrame(columns=['Postcode','Borough','Neighbourhood'],index=[1])
df.size
df.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
rows=My_table.find_all('tr')

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    l.append(row)
df=pd.DataFrame(l, columns=['Postcode','Borough','Neighbourhood'])

# %%
df=df[df['Borough']!='Not assigned']

# %%
df=df.drop(0)

# %%
df
# Out:
#     Postcode           Borough  \
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# 33       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# 39       M9C         Etobicoke
# ..       ...               ...
# 236      M9V         Etobicoke
# 237      M1W       Scarborough
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
#
#                                          Neighbourhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# ..                                                 ...
# 236                                        Thistletown
# 237                                    L'Amoreaux West
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
df['Neighbourhood'].replace('Not assigned', 'Queen\'s Park',inplace=True)
df
# Out:
#     Postcode           Borough  \
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# 33       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# 39       M9C         Etobicoke
# ..       ...               ...
# 236      M9V         Etobicoke
# 237      M1W       Scarborough
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
#
#                                          Neighbourhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Queen's Park
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# ..                                                 ...
# 236                                        Thistletown
# 237                                    L'Amoreaux West
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# ## In the next few steps we will read geolocation data as csv and then merge this with the existing dataframe

# %%
geoloc=pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geoloc.columns = ['Postcode', 'Latitude', 'Longitude']

# %%
df_location=pd.merge(df,geoloc,on=['Postcode'],how='inner')

# %%
df_location
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 9        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 12       M4B         East York
# 13       M5B  Downtown Toronto
# 14       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M9B         Etobicoke
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M1C       Scarborough
# 24       M3C        North York
# 25       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# ..       ...               ...
# 181      M9V         Etobicoke
# 182      M1W       Scarborough
# 183      M4W  Downtown Toronto
# 184      M5W  Downtown Toronto
# 185      M8W         Etobicoke
# 186      M8W         Etobicoke
# 187      M9W         Etobicoke
# 188      M1X       Scarborough
# 189      M4X  Downtown Toronto
# 190      M4X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 192      M5X  Downtown Toronto
# 193      M8X         Etobicoke
# 194      M8X         Etobicoke
# 195      M8X         Etobicoke
# 196      M4Y  Downtown Toronto
# 197      M7Y      East Toronto
# 198      M8Y         Etobicoke
# 199      M8Y         Etobicoke
# 200      M8Y         Etobicoke
# 201      M8Y         Etobicoke
# 202      M8Y         Etobicoke
# 203      M8Y         Etobicoke
# 204      M8Y         Etobicoke
# 205      M8Y         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
# 210      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                                         Harbourfront  43.654260 -79.360636
# 3                                          Regent Park  43.654260 -79.360636
# 4                                     Lawrence Heights  43.718518 -79.464763
# 5                                       Lawrence Manor  43.718518 -79.464763
# 6                                         Queen's Park  43.662301 -79.389494
# 7                                     Islington Avenue  43.667856 -79.532242
# 8                                                Rouge  43.806686 -79.194353
# 9                                              Malvern  43.806686 -79.194353
# 10                                     Don Mills North  43.745906 -79.352188
# 11                                    Woodbine Gardens  43.706397 -79.309937
# 12                                       Parkview Hill  43.706397 -79.309937
# 13                                             Ryerson  43.657162 -79.378937
# 14                                     Garden District  43.657162 -79.378937
# 15                                           Glencairn  43.709577 -79.445073
# 16                                          Cloverdale  43.650943 -79.554724
# 17                                           Islington  43.650943 -79.554724
# 18                                        Martin Grove  43.650943 -79.554724
# 19                                    Princess Gardens  43.650943 -79.554724
# 20                                     West Deane Park  43.650943 -79.554724
# 21                                      Highland Creek  43.784535 -79.160497
# 22                                          Rouge Hill  43.784535 -79.160497
# 23                                          Port Union  43.784535 -79.160497
# 24                                     Flemingdon Park  43.725900 -79.340923
# 25                                     Don Mills South  43.725900 -79.340923
# 26                                    Woodbine Heights  43.695344 -79.318389
# 27                                      St. James Town  43.651494 -79.375418
# 28                                  Humewood-Cedarvale  43.693781 -79.428191
# 29                                   Bloordale Gardens  43.643515 -79.577201
# ..                                                 ...        ...        ...
# 181                                        Thistletown  43.739416 -79.588437
# 182                                    L'Amoreaux West  43.799525 -79.318389
# 183                                           Rosedale  43.679563 -79.377529
# 184                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 185                                          Alderwood  43.602414 -79.543484
# 186                                        Long Branch  43.602414 -79.543484
# 187                                          Northwest  43.706748 -79.594054
# 188                                        Upper Rouge  43.836125 -79.205636
# 189                                        Cabbagetown  43.667967 -79.367675
# 190                                     St. James Town  43.667967 -79.367675
# 191                               First Canadian Place  43.648429 -79.382280
# 192                                   Underground city  43.648429 -79.382280
# 193                                       The Kingsway  43.653654 -79.506944
# 194                                    Montgomery Road  43.653654 -79.506944
# 195                                     Old Mill North  43.653654 -79.506944
# 196                               Church and Wellesley  43.665860 -79.383160
# 197  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 198                                         Humber Bay  43.636258 -79.498509
# 199                                   King's Mill Park  43.636258 -79.498509
# 200                           Kingsway Park South East  43.636258 -79.498509
# 201                                          Mimico NE  43.636258 -79.498509
# 202                                     Old Mill South  43.636258 -79.498509
# 203                                 The Queensway East  43.636258 -79.498509
# 204                              Royal York South East  43.636258 -79.498509
# 205                                           Sunnylea  43.636258 -79.498509
# 206                           Kingsway Park South West  43.628841 -79.520999
# 207                                          Mimico NW  43.628841 -79.520999
# 208                                 The Queensway West  43.628841 -79.520999
# 209                              Royal York South West  43.628841 -79.520999
# 210                                     South of Bloor  43.628841 -79.520999
#
# [211 rows x 5 columns]

# %% [markdown]
# ### Using the shape function to get list of rows and columns of the new dataframe

# %%
df_location.shape
# Out:
# (211, 5)

# %% [markdown]
# #### Importing various libraries to
# 1. read gelocation data (geocoder)
# 2. visualize(folium)
# 3. clustering analysis(sklearn)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
website_url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup=BeautifulSoup(website_url,'lxml')
My_table=soup.find('table',{'class':'wikitable sortable'})
df=pd.DataFrame(columns=['Postcode','Borough','Neighbourhood'],index=[1])
df.size
df.columns
rows=My_table.find_all('tr')

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    l.append(row)
df=pd.DataFrame(l, columns=['Postcode','Borough','Neighbourhood'])
df=df.drop(0)

# %% [markdown]
# * Create a dataframe from original dataframe by filtering Boroughs with value 'Toronto'
# * Then perform a merge operation of Dataframe and geolocation data

# %%
df_can=df[df['Borough'].str.contains('Toronto')]

# %%
df_can
# Out:
#     Postcode           Borough  \
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 35       M5C  Downtown Toronto
# 48       M4E      East Toronto
# 49       M5E  Downtown Toronto
# 58       M5G  Downtown Toronto
# 59       M6G  Downtown Toronto
# 69       M5H  Downtown Toronto
# 70       M5H  Downtown Toronto
# 71       M5H  Downtown Toronto
# 72       M6H      West Toronto
# 73       M6H      West Toronto
# 84       M5J  Downtown Toronto
# 85       M5J  Downtown Toronto
# 86       M5J  Downtown Toronto
# 87       M6J      West Toronto
# 88       M6J      West Toronto
# 98       M4K      East Toronto
# 99       M4K      East Toronto
# 100      M5K  Downtown Toronto
# 101      M5K  Downtown Toronto
# 102      M6K      West Toronto
# 103      M6K      West Toronto
# 104      M6K      West Toronto
# 114      M4L      East Toronto
# 115      M4L      East Toronto
# 116      M5L  Downtown Toronto
# 117      M5L  Downtown Toronto
# 130      M4M      East Toronto
# 145      M4N   Central Toronto
# 146      M5N   Central Toronto
# 157      M4P   Central Toronto
# 158      M5P   Central Toronto
# 159      M5P   Central Toronto
# 160      M6P      West Toronto
# 161      M6P      West Toronto
# 169      M4R   Central Toronto
# 170      M5R   Central Toronto
# 171      M5R   Central Toronto
# 172      M5R   Central Toronto
# 173      M6R      West Toronto
# 174      M6R      West Toronto
# 184      M4S   Central Toronto
# 185      M5S  Downtown Toronto
# 186      M5S  Downtown Toronto
# 187      M6S      West Toronto
# 188      M6S      West Toronto
# 197      M4T   Central Toronto
# 198      M4T   Central Toronto
# 199      M5T  Downtown Toronto
# 200      M5T  Downtown Toronto
# 201      M5T  Downtown Toronto
# 212      M4V   Central Toronto
# 213      M4V   Central Toronto
# 214      M4V   Central Toronto
# 215      M4V   Central Toronto
# 216      M4V   Central Toronto
# 217      M5V  Downtown Toronto
# 218      M5V  Downtown Toronto
# 219      M5V  Downtown Toronto
# 220      M5V  Downtown Toronto
# 221      M5V  Downtown Toronto
# 222      M5V  Downtown Toronto
# 223      M5V  Downtown Toronto
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
#
#                                          Neighbourhood
# 5                                         Harbourfront
# 6                                          Regent Park
# 18                                             Ryerson
# 19                                     Garden District
# 35                                      St. James Town
# 48                                         The Beaches
# 49                                         Berczy Park
# 58                                  Central Bay Street
# 59                                            Christie
# 69                                            Adelaide
# 70                                                King
# 71                                            Richmond
# 72                                  Dovercourt Village
# 73                                            Dufferin
# 84                                   Harbourfront East
# 85                                     Toronto Islands
# 86                                       Union Station
# 87                                     Little Portugal
# 88                                             Trinity
# 98                                   The Danforth West
# 99                                           Riverdale
# 100                                    Design Exchange
# 101                            Toronto Dominion Centre
# 102                                           Brockton
# 103                                   Exhibition Place
# 104                                   Parkdale Village
# 114                                   The Beaches West
# 115                                       India Bazaar
# 116                                     Commerce Court
# 117                                     Victoria Hotel
# 130                                    Studio District
# 145                                      Lawrence Park
# 146                                           Roselawn
# 157                                   Davisville North
# 158                                  Forest Hill North
# 159                                   Forest Hill West
# 160                                          High Park
# 161                                 The Junction South
# 169                                 North Toronto West
# 170                                          The Annex
# 171                                      North Midtown
# 172                                          Yorkville
# 173                                           Parkdale
# 174                                       Roncesvalles
# 184                                         Davisville
# 185                                            Harbord
# 186                              University of Toronto
# 187                                          Runnymede
# 188                                            Swansea
# 197                                         Moore Park
# 198                                    Summerhill East
# 199                                          Chinatown
# 200                                        Grange Park
# 201                                  Kensington Market
# 212                                          Deer Park
# 213                                     Forest Hill SE
# 214                                          Rathnelly
# 215                                         South Hill
# 216                                    Summerhill West
# 217                                           CN Tower
# 218                                      Bathurst Quay
# 219                                     Island airport
# 220                                  Harbourfront West
# 221                                   King and Spadina
# 222                                      Railway Lands
# 223                                      South Niagara
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern

# %%
geoloc=pd.read_csv('http://cocl.us/Geospatial_data')
geoloc.columns = ['Postcode', 'Latitude', 'Longitude']
df_location=pd.merge(df_can,geoloc,on=['Postcode'],how='inner')

# %%
df_location
# Out:
#    Postcode           Borough  \
# 0       M5A  Downtown Toronto
# 1       

        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Create a dataframe for cluster analysis

# %%
df_clus=df_location.drop(['Borough','Neighbourhood','Postcode'],1)

# %%
df_clus
# Out:
#      Latitude  Longitude
# 0   43.654260 -79.360636
# 1   43.654260 -79.360636
# 2   43.657162 -79.378937
# 3   43.657162 -79.378937
# 4   43.651494 -79.375418
# 5   43.676357 -79.293031
# 6   43.644771 -79.373306
# 7   43.657952 -79.387383
# 8   43.669542 -79.422564
# 9   43.650571 -79.384568
# 10  43.650571 -79.384568
# 11  43.650571 -79.384568
# 12  43.669005 -79.442259
# 13  43.669005 -79.442259
# 14  43.640816 -79.381752
# 15  43.640816 -79.381752
# 16  43.640816 -79.381752
# 17  43.647927 -79.419750
# 18  43.647927 -79.419750
# 19  43.679557 -79.352188
# 20  43.679557 -79.352188
# 21  43.647177 -79.381576
# 22  43.647177 -79.381576
# 23  43.636847 -79.428191
# 24  43.636847 -79.428191
# 25  43.636847 -79.428191
# 26  43.668999 -79.315572
# 27  43.668999 -79.315572
# 28  43.648198 -79.379817
# 29  43.648198 -79.379817
# 30  43.659526 -79.340923
# 31  43.728020 -79.388790
# 32  43.711695 -79.416936
# 33  43.712751 -79.390197
# 34  43.696948 -79.411307
# 35  43.696948 -79.411307
# 36  43.661608 -79.464763
# 37  43.661608 -79.464763
# 38  43.715383 -79.405678
# 39  43.672710 -79.405678
# 40  43.672710 -79.405678
# 41  43.672710 -79.405678
# 42  43.648960 -79.456325
# 43  43.648960 -79.456325
# 44  43.704324 -79.388790
# 45  43.662696 -79.400049
# 46  43.662696 -79.400049
# 47  43.651571 -79.484450
# 48  43.651571 -79.484450
# 49  43.689574 -79.383160
# 50  43.689574 -79.383160
# 51  43.653206 -79.400049
# 52  43.653206 -79.400049
# 53  43.653206 -79.400049
# 54  43.686412 -79.400049
# 55  43.686412 -79.400049
# 56  43.686412 -79.400049
# 57  43.686412 -79.400049
# 58  43.686412 -79.400049
# 59  43.628947 -79.394420
# 60  43.628947 -79.394420
# 61  43.628947 -79.394420
# 62  43.628947 -79.394420
# 63  43.628947 -79.394420
# 64  43.628947 -79.394420
# 65  43.628947 -79.394420
# 66  43.679563 -79.377529
# 67  43.646435 -79.374846
# 68  43.667967 -79.367675
# 69  43.667967 -79.367675
# 70  43.648429 -79.382280
# 71  43.648429 -79.382280
# 72  43.665860 -79.383160
# 73  43.662744 -79.321558

# %%
num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(df_clus)
labels = k_means.labels_

print(labels.dtype)
# Out:
# int32

# %%
df_clus['Labels']=labels
df_clus
# Out:
#      Latitude  Longitude  Labels
# 0   43.654260 -79.360636       2
# 1   43.654260 -79.360636       2
# 2   43.657162 -79.378937       2
# 3   43.657162 -79.378937       2
# 4   43.651494 -79.375418       2
# 5   43.676357 -79.293031       2
# 6   43.644771 -79.373306       2
# 7   43.657952 -79.387383       2
# 8   43.669542 -79.422564       0
# 9   43.650571 -79.384568       2
# 10  43.650571 -79.384568       2
# 11  43.650571 -79.384568       2
# 12  43.669005 -79.442259       0
# 13  43.669005 -79.442259       0
# 14  43.640816 -79.381752       2
# 15  43.640816 -79.381752       2
# 16  43.640816 -79.381752       2
# 17  43.647927 -79.419750       0
# 18  43.647927 -79.419750       0
# 19  43.679557 -79.352188       2
# 20  43.679557 -79.352188       2
# 21  43.647177 -79.381576       2
# 22  43.647177 -79.381576       2
# 23  43.636847 -79.428191       0
# 24  43.636847 -79.428191       0
# 25  43.636847 -79.428191       0
# 26  43.668999 -79.315572       2
# 27  43.668999 -79.315572       2
# 28  43.648198 -79.379817       2
# 29  43.648198 -79.379817       2
# 30  43.659526 -79.340923       2
# 31  43.728020 -79.388790       1
# 32  43.711695 -79.416936       1
# 33  43.712751 -79.390197       1
# 34  43.696948 -79.411307       1
# 35  43.696948 -79.411307       1
# 36  43.661608 -79.464763       0
# 37  43.661608 -79.464763       0
# 38  43.715383 -79.405678       1
# 39  43.672710 -79.405678       1
# 40  43.672710 -79.405678       1
# 41  43.672710 -79.405678       1
# 42  43.648960 -79.456325       0
# 43  43.648960 -79.456325       0
# 44  43.704324 -79.388790       1
# 45  43.662696 -79.400049       2
# 46  43.662696 -79.400049       2
# 47  43.651571 -79.484450       0
# 48  43.651571 -79.484450       0
# 49  43.689574 -79.383160       1
# 50  43.689574 -79.383160       1
# 51  43.653206 -79.400049       2
# 52  43.653206 -79.400049       2
# 53  43.653206 -79.400049       2
# 54  43.686412 -79.400049       1
# 55  43.686412 -79.400049       1
# 56  43.686412 -79.400049       1
# 57  43.686412 -79.400049       1
# 58  43.686412 -79.400049       1
# 59  43.628947 -79.394420       2
# 60  43.628947 -79.394420       2
# 61  43.628947 -79.394420       2
# 62  43.628947 -79.394420       2
# 63  43.628947 -79.394420       2
# 64  43.628947 -79.394420       2
# 65  43.628947 -79.394420       2
# 66  43.679563 -79.377529       1
# 67  43.646435 -79.374846       2
# 68  43.667967 -79.367675       2
# 69  43.667967 -79.367675       2
# 70  43.648429 -79.382280       2
# 71  43.648429 -79.382280       2
# 72  43.665860 -79.383160       2
# 73  43.662744 -79.321558       2

# %%
# # create map
# map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
# kclusters=3

# # set color scheme for the clusters
# x = np.arange(kclusters)
# ys = [i + x + (i*x)**2 for i in range(kclusters)]
# colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
# rainbow = [colors.rgb2hex(i) for i in colors_array]
# rainbow
# # add markers to the map
# markers_colors = []
# for lat, lon, label in zip(df_clus['Latitude'], df_clus['Longitude'], df_clus['Labels']):
#     label = folium.Popup(str(bor) + ' Cluster ' + str(label), parse_html=True)
#     folium.CircleMarker(
#         [lat, lon],
#         radius=5,
#         popup=label,
#         color=rainbow[label-1],
#         fill=True,
#         fill_color=rainbow[label-1],
#         fill_opacity=0.7).add_to(map_clusters)
       
# map_clusters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-a02f5a464ebd> in <module>
#      17         radius=5,
#      18         popup=label,
# ---> 19         color=rainbow[label-1],
#      20         fill=True,
#      21         fill_color=rainbow[label-1],
#
# TypeError: unsupported operand type(s) for -: 'Popup' and 'int'
