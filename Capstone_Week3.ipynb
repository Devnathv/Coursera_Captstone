# %% [markdown]
# # Importing Libraries for the Porject

# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# *Use the Requests and Beautiful soup packages for webscraping data*

# %%
website_url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
soup=BeautifulSoup(website_url,'lxml')

# %%
My_table=soup.find('table',{'class':'wikitable sortable'})

# %% [markdown]
# ## Data transformation steps
# 1. Assign columns to the empty dataframe
# 2. Peform various clean up operations on the dataframe
#     * Remove Boroughs not assigned
#     * Assign Neighbourhoods that are not assigned with those of Boroughs

# %%
df=pd.DataFrame(columns=['Postcode','Borough','Neighbourhood'],index=[1])
df.size
df.columns
# Out:
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
rows=My_table.find_all('tr')

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    l.append(row)
df=pd.DataFrame(l, columns=['Postcode','Borough','Neighbourhood'])

# %%
df=df[df['Borough']!='Not assigned']
dftt=df.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 0      None              None              None
# 3       M3A        North York         Parkwoods
# 4       M4A        North York  Victoria Village
# 5       M5A  Downtown Toronto      Harbourfront
# 6       M5A  Downtown Toronto       Regent Park
# 7       M6A        North York  Lawrence Heights
# 8       M6A        North York    Lawrence Manor
# 9       M7A      Queen's Park      Not assigned
# 11      M9A         Etobicoke  Islington Avenue
# 12      M1B       Scarborough             Rouge

# %%
df.drop(0)
df
# Out:
#     Postcode           Borough  \
# 0       None              None
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M1C       Scarborough
# 32       M3C        North York
# 33       M3C        North York
# 34       M4C         East York
# 35       M5C  Downtown Toronto
# 36       M6C              York
# 39       M9C         Etobicoke
# 40       M9C         Etobicoke
# 41       M9C         Etobicoke
# 42       M9C         Etobicoke
# 43       M1E       Scarborough
# 44       M1E       Scarborough
# 45       M1E       Scarborough
# 48       M4E      East Toronto
# 49       M5E  Downtown Toronto
# 50       M6E              York
# 54       M1G       Scarborough
# 57       M4G         East York
# 58       M5G  Downtown Toronto
# 59       M6G  Downtown Toronto
# 63       M1H       Scarborough
# 64       M2H        North York
# 65       M3H        North York
# 66       M3H        North York
# 67       M3H        North York
# 68       M4H         East York
# 69       M5H  Downtown Toronto
# 70       M5H  Downtown Toronto
# 71       M5H  Downtown Toronto
# 72       M6H      West Toronto
# 73       M6H      West Toronto
# 77       M1J       Scarborough
# 78       M2J        North York
# 79       M2J        North York
# 80       M2J        North York
# 81       M3J        North York
# 82       M3J        North York
# 83       M4J         East York
# 84       M5J  Downtown Toronto
# 85       M5J  Downtown Toronto
# 86       M5J  Downtown Toronto
# 87       M6J      West Toronto
# 88       M6J      West Toronto
# 92       M1K       Scarborough
# 93       M1K       Scarborough
# 94       M1K       Scarborough
# 95       M2K        North York
# 96       M3K        North York
# 97       M3K        North York
# 98       M4K      East Toronto
# 99       M4K      East Toronto
# 100      M5K  Downtown Toronto
# 101      M5K  Downtown Toronto
# 102      M6K      West Toronto
# 103      M6K      West Toronto
# 104      M6K      West Toronto
# 108      M1L       Scarborough
# 109      M1L       Scarborough
# 110      M1L       Scarborough
# 111      M2L        North York
# 112      M2L        North York
# 113      M3L        North York
# 114      M4L      East Toronto
# 115      M4L      East Toronto
# 116      M5L  Downtown Toronto
# 117      M5L  Downtown Toronto
# 118      M6L        North York
# 119      M6L        North York
# 120      M6L        North York
# 123      M9L        North York
# 124      M1M       Scarborough
# 125      M1M       Scarborough
# 126      M1M       Scarborough
# 127      M2M        North York
# 128      M2M        North York
# 129      M3M        North York
# 130      M4M      East Toronto
# 131      M5M        North York
# 132      M5M        North York
# 133      M6M              York
# 134      M6M              York
# 135      M6M              York
# 136      M6M              York
# 139      M9M        North York
# 140      M9M        North York
# 141      M1N       Scarborough
# 142      M1N       Scarborough
# 143      M2N        North York
# 144      M3N        North York
# 145      M4N   Central Toronto
# 146      M5N   Central Toronto
# 147      M6N              York
# 148      M6N              York
# 151      M9N              York
# 152      M1P       Scarborough
# 153      M1P       Scarborough
# 154      M1P       Scarborough
# 155      M2P        North York
# 157      M4P   Central Toronto
# 158      M5P   Central Toronto
# 159      M5P   Central Toronto
# 160      M6P      West Toronto
# 161      M6P      West Toronto
# 164      M9P         Etobicoke
# 165      M1R       Scarborough
# 166      M1R       Scarborough
# 167      M2R        North York
# 169      M4R   Central Toronto
# 170      M5R   Central Toronto
# 171      M5R   Central Toronto
# 172      M5R   Central Toronto
# 173      M6R      West Toronto
# 174      M6R      West Toronto
# 175      M7R       Mississauga
# 177      M9R         Etobicoke
# 178      M9R         Etobicoke
# 179      M9R         Etobicoke
# 180      M9R         Etobicoke
# 181      M1S       Scarborough
# 184      M4S   Central Toronto
# 185      M5S  Downtown Toronto
# 186      M5S  Downtown Toronto
# 187      M6S      West Toronto
# 188      M6S      West Toronto
# 192      M1T       Scarborough
# 193      M1T       Scarborough
# 194      M1T       Scarborough
# 197      M4T   Central Toronto
# 198      M4T   Central Toronto
# 199      M5T  Downtown Toronto
# 200      M5T  Downtown Toronto
# 201      M5T  Downtown Toronto
# 206      M1V       Scarborough
# 207      M1V       Scarborough
# 208      M1V       Scarborough
# 209      M1V       Scarborough
# 212      M4V   Central Toronto
# 213      M4V   Central Toronto
# 214      M4V   Central Toronto
# 215      M4V   Central Toronto
# 216      M4V   Central Toronto
# 217      M5V  Downtown Toronto
# 218      M5V  Downtown Toronto
# 219      M5V  Downtown Toronto
# 220      M5V  Downtown Toronto
# 221      M5V  Downtown Toronto
# 222      M5V  Downtown Toronto
# 223      M5V  Downtown Toronto
# 226      M8V         Etobicoke
# 227      M8V         Etobicoke
# 228      M8V         Etobicoke
# 229      M9V         Etobicoke
# 230      M9V         Etobicoke
# 231      M9V         Etobicoke
# 232      M9V         Etobicoke
# 233      M9V         Etobicoke
# 234      M9V         Etobicoke
# 235      M9V         Etobicoke
# 236      M9V         Etobicoke
# 237      M1W       Scarborough
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 263      M4Y  Downtown Toronto
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                                 None
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                                         Harbourfront
# 6                                          Regent Park
# 7                                     Lawrence Heights
# 8                                       Lawrence Manor
# 9                                         Not assigned
# 11                                    Islington Avenue
# 12                                               Rouge
# 13                                             Malvern
# 15                                     Don Mills North
# 16                                    Woodbine Gardens
# 17                                       Parkview Hill
# 18                                             Ryerson
# 19                                     Garden District
# 20                                           Glencairn
# 23                                          Cloverdale
# 24                                           Islington
# 25                                        Martin Grove
# 26                                    Princess Gardens
# 27                                     West Deane Park
# 28                                      Highland Creek
# 29                                          Rouge Hill
# 30                                          Port Union
# 32                                     Flemingdon Park
# 33                                     Don Mills South
# 34                                    Woodbine Heights
# 35                                      St. James Town
# 36                                  Humewood-Cedarvale
# 39                                   Bloordale Gardens
# 40                                            Eringate
# 41                                       Markland Wood
# 42                                   Old Burnhamthorpe
# 43                                           Guildwood
# 44                                         Morningside
# 45                                           West Hill
# 48                                         The Beaches
# 49                                         Berczy Park
# 50                                 Caledonia-Fairbanks
# 54                                              Woburn
# 57                                             Leaside
# 58                                  Central Bay Street
# 59                                            Christie
# 63                                           Cedarbrae
# 64                                   Hillcrest Village
# 65                                      Bathurst Manor
# 66                                     Downsview North
# 67                                      Wilson Heights
# 68                                    Thorncliffe Park
# 69                                            Adelaide
# 70                                                King
# 71                                            Richmond
# 72                                  Dovercourt Village
# 73                                            Dufferin
# 77                                 Scarborough Village
# 78                                            Fairview
# 79                                          Henry Farm
# 80                                              Oriole
# 81                                      Northwood Park
# 82                                     York University
# 83                                        East Toronto
# 84                                   Harbourfront East
# 85                                     Toronto Islands
# 86                                       Union Station
# 87                                     Little Portugal
# 88                                             Trinity
# 92                                East Birchmount Park
# 93                                             Ionview
# 94                                        Kennedy Park
# 95                                     Bayview Village
# 96                                         CFB Toronto
# 97                                      Downsview East
# 98                                   The Danforth West
# 99                                           Riverdale
# 100                                    Design Exchange
# 101                            Toronto Dominion Centre
# 102                                           Brockton
# 103                                   Exhibition Place
# 104                                   Parkdale Village
# 108                                           Clairlea
# 109                                        Golden Mile
# 110                                           Oakridge
# 111                                       Silver Hills
# 112                                         York Mills
# 113                                     Downsview West
# 114                                   The Beaches West
# 115                                       India Bazaar
# 116                                     Commerce Court
# 117                                     Victoria Hotel
# 118                                          Downsview
# 119                                         North Park
# 120                                        Upwood Park
# 123                                      Humber Summit
# 124                                         Cliffcrest
# 125                                          Cliffside
# 126                           Scarborough Village West
# 127                                        Newtonbrook
# 128                                         Willowdale
# 129                                  Downsview Central
# 130                                    Studio District
# 131                                       Bedford Park
# 132                                Lawrence Manor East
# 133                                            Del Ray
# 134                                         Keelesdale
# 135                                       Mount Dennis
# 136                                        Silverthorn
# 139                                              Emery
# 140                                          Humberlea
# 141                                        Birch Cliff
# 142                                     Cliffside West
# 143                                   Willowdale South
# 144                                Downsview Northwest
# 145                                      Lawrence Park
# 146                                           Roselawn
# 147                                 The Junction North
# 148                                          Runnymede
# 151                                             Weston
# 152                                        Dorset Park
# 153                            Scarborough Town Centre
# 154                                    Wexford Heights
# 155                                    York Mills West
# 157                                   Davisville North
# 158                                  Forest Hill North
# 159                                   Forest Hill West
# 160                                          High Park
# 161                                 The Junction South
# 164                                          Westmount
# 165                                           Maryvale
# 166                                            Wexford
# 167                                    Willowdale West
# 169                                 North Toronto West
# 170                                          The Annex
# 171                                      North Midtown
# 172                                          Yorkville
# 173                                           Parkdale
# 174                                       Roncesvalles
# 175              Canada Post Gateway Processing Centre
# 177                                  Kingsview Village
# 178                               Martin Grove Gardens
# 179                                   Richview Gardens
# 180                                       St. Phillips
# 181                                          Agincourt
# 184                                         Davisville
# 185                                            Harbord
# 186                              University of Toronto
# 187                                          Runnymede
# 188                                            Swansea
# 192                                     Clarks Corners
# 193                                           Sullivan
# 194                                      Tam O'Shanter
# 197                                         Moore Park
# 198                                    Summerhill East
# 199                                          Chinatown
# 200                                        Grange Park
# 201                                  Kensington Market
# 206                                    Agincourt North
# 207                                    L'Amoreaux East
# 208                                           Milliken
# 209                                       Steeles East
# 212                                          Deer Park
# 213                                     Forest Hill SE
# 214                                          Rathnelly
# 215                                         South Hill
# 216                                    Summerhill West
# 217                                           CN Tower
# 218                                      Bathurst Quay
# 219                                     Island airport
# 220                                  Harbourfront West
# 221                                   King and Spadina
# 222                                      Railway Lands
# 223                                      South Niagara
# 226                                  Humber Bay Shores
# 227                                       Mimico South
# 228                                        New Toronto
# 229                                     Albion Gardens
# 230                                   Beaumond Heights
# 231                                         Humbergate
# 232                                          Jamestown
# 233                                        Mount Olive
# 234                                        Silverstone
# 235                                      South Steeles
# 236                                        Thistletown
# 237                                    L'Amoreaux West
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 263                               Church and Wellesley
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor

# %%
df['Neighbourhood'].replace('Not assigned', 'Queen\'s Park',inplace=True)
df.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\itdxv01\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-2d965ee59d0a> in <module>
# ----> 1 df['Neighbourhood'].replace('Not assigned', 'Queen\'s Park',inplace=True)
#       2 df.shape
#
# c:\users\itdxv01\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# c:\users\itdxv01\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# c:\users\itdxv01\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Neighbourhood'

# %% [markdown]
# ## In the next few steps we will read geolocation data as csv and then merge this with the existing dataframe

# %%
geoloc=pd.read_csv('http://cocl.us/Geospatial_data')

# %%
geoloc.columns = ['Postcode', 'Latitude', 'Longitude']

# %%
df_location=pd.merge(df,geoloc,on=['Postcode'],how='inner')

# %%
df_location
# Out:
#    Postcode           Borough  \
# 0       M5A  Downtown Toronto
# 1       M5A  Downtown Toronto
# 2       M5B  Downtown Toronto
# 3       M5B  Downtown Toronto
# 4       M5C  Downtown Toronto
# 5       M4E      East Toronto
# 6       M5E  Downtown Toronto
# 7       M5G  Downtown Toronto
# 8       M6G  Downtown Toronto
# 9       M5H  Downtown Toronto
# 10      M5H  Downtown Toronto
# 11      M5H  Downtown Toronto
# 12      M6H      West Toronto
# 13      M6H      West Toronto
# 14      M5J  Downtown Toronto
# 15      M5J  Downtown Toronto
# 16      M5J  Downtown Toronto
# 28                                     Commerce Court  43.648198 -79.379817
# 29                                     Victoria Hotel  43.648198 -79.379817
# 30                                    Studio District  43.659526 -79.340923
# 31                                      Lawrence Park  43.728020 -79.388790
# 32                                           Roselawn  43.711695 -79.416936
# 33                                   Davisville North  43.712751 -79.390197
# 34                                  Forest Hill North  43.696948 -79.411307
# 35                                   Forest Hill West  43.696948 -79.411307
# 36                                          High Park  43.661608 -79.464763
# 37                                 The Junction South  43.661608 -79.464763
# 38                                 North Toronto West  43.715383 -79.405678
# 39                                          The Annex  43.672710 -79.405678
# 40                                      North Midtown  43.672710 -79.405678
# 41                                          Yorkville  43.672710 -79.405678
# 42                                           Parkdale  43.648960 -79.456325
# 43                                       Roncesvalles  43.648960 -79.456325
# 44                                         Davisville  43.704324 -79.388790
# 45                                            Harbord  43.662696 -79.400049
# 46                              University of Toronto  43.662696 -79.400049
# 47                                          Runnymede  43.651571 -79.484450
# 48                                            Swansea  43.651571 -79.484450
# 49                                         Moore Park  43.689574 -79.383160
# 50                                    Summerhill East  43.689574 -79.383160
# 51                                          Chinatown  43.653206 -79.400049
# 52                                        Grange Park  43.653206 -79.400049
# 53                                  Kensington Market  43.653206 -79.400049
# 54                                          Deer Park  43.686412 -79.400049
# 55                                     Forest Hill SE  43.686412 -79.400049
# 56                                          Rathnelly  43.686412 -79.400049
# 57                                         South Hill  43.686412 -79.400049
# 58                                    Summerhill West  43.686412 -79.400049
# 59                                           CN Tower  43.628947 -79.394420
# 60                                      Bathurst Quay  43.628947 -79.394420
# 61                                     Island airport  43.628947 -79.394420
# 62                                  Harbourfront West  43.628947 -79.394420
# 63                                   King and Spadina  43.628947 -79.394420
# 64                                      Railway Lands  43.628947 -79.394420
# 65                                      South Niagara  43.628947 -79.394420
# 66                                           Rosedale  43.679563 -79.377529
# 67                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 68                                        Cabbagetown  43.667967 -79.367675
# 69                                     St. James Town  43.667967 -79.367675
# 70                               First Canadian Place  43.648429 -79.382280
# 71                                   Underground city  43.648429 -79.382280
# 72                               Church and Wellesley  43.665860 -79.383160
# 73  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %% [markdown]
# ### Using the shape function to get list of rows and columns of the new dataframe

# %%
df_location.shape
# Out:
# (211, 5)

# %% [markdown]
# #### Importing various libraries to
# 1. read gelocation data (geocoder)
# 2. visualize(folium)
# 3. clustering analysis(sklearn)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
website_url=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup=BeautifulSoup(website_url,'lxml')
My_table=soup.find('table',{'class':'wikitable sortable'})
df=pd.DataFrame(columns=['Postcode','Borough','Neighbourhood'],index=[1])
df.size
df.columns
rows=My_table.find_all('tr')

l = []
for tr in rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    l.append(row)
df=pd.DataFrame(l, columns=['Postcode','Borough','Neighbourhood'])
df=df.drop(0)
df.shape
df_can=df[df['Borough']!='Not assigned']
df_can.shape
df_tor=df_can.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df_tor.columns = ['Postcode', 'Borough', 'Neighborhood']
df_tor.shape
# Out:
# (103, 3)

# %% [markdown]
# * Create a dataframe from original dataframe by filtering Boroughs with value 'Toronto'
# * Then perform a merge operation of Dataframe and geolocation data

# %%
df_can=df[df['Borough'].str.contains('Toronto')] 
df_can.shape

# %%
df_tor.shape
# Out:
# (74, 3)

# %%
geoloc=pd.read_csv('http://cocl.us/Geospatial_data')
geoloc.columns = ['Postcode', 'Latitude', 'Longitude']
df_location=pd.merge(df_can,geoloc,on=['Postcode'],how='inner')

# %%
df_location
# Out:
#    Postcode           Borough  \
# 0       M5A  Downtown Toronto
# 1       M5A  Downtown Toronto
# 2       M5B  Downtown Toronto
# 3       M5B  Downtown Toronto
# 4       M5C  Downtown Toronto
# 5       M4E      East Toronto
# 6       M5E  Downtown Toronto
# 7       M5G  Downtown Toronto
# 8       M6G  Downtown Toronto
# 9       M5H  Downtown Toronto
# 10      M5H  Downtown Toronto
# 11      M5H  Downtown Toronto
# 12      M6H      West Toronto
# 13      M6H      West Toronto
# 14      M5J  Downtown Toronto
# 15      M5J  Downtown Toronto
# 16      M5J  Downtown Toronto
# 17      M6J      West Toronto
# 18      M6J      West Toronto
# 19      M4K      East Toronto
# 20      M4K      East Toronto
# 21      M5K  Downtown Toronto
# 22      M5K  Downtown Toronto
# 23      M6K      West Toronto
# 24      M6K      West Toronto
# 25      M6K      West Toronto
# 26      M4L      East Toronto
# 27      M4L      East Toronto
# 28      M5L  Downtown Toronto
# 29      M5L  Downtown Toronto
# 30      M4M      East Toronto
# 31      M4N   Central Toronto
# 32      M5N   Central Toronto
# 33      M4P   Central Toronto
# 34      M5P   Central Toronto
# 35      M5P   Central Toronto
# 36      M6P      West Toronto
# 37      M6P      West Toronto
# 38      M4R   Central Toronto
# 39      M5R   Central Toronto
# 40      M5R   Central Toronto
# 41      M5R   Central Toronto
# 42      M6R      West Toronto
# 43      M6R      West Toronto
# 44      M4S   Central Toronto
# 45      M5S  Downtown Toronto
# 46      M5S  Downtown Toronto
# 47      M6S      West Toronto
# 48      M6S      West Toronto
# 49      M4T   Central Toronto
# 50      M4T   Central Toronto
# 51      M5T  Downtown Toronto
# 52      M5T  Downtown Toronto
# 53      M5T  Downtown Toronto
# 54      M4V   Central Toronto
# 55      M4V   Central Toronto
# 56      M4V   Central Toronto
# 57      M4V   Central Toronto
# 58      M4V   Central Toronto
# 59      M5V  Downtown Toronto
# 60      M5V  Downtown Toronto
# 61      M5V  Downtown Toronto
# 62      M5V  Downtown Toronto
# 63      M5V  Downtown Toronto
# 64      M5V  Downtown Toronto
# 65      M5V  Downtown Toronto
# 66      M4W  Downtown Toronto
# 67      M5W  Downtown Toronto
# 68      M4X  Downtown Toronto
# 69      M4X  Downtown Toronto
# 70      M5X  Downtown Toronto
# 71      M5X  Downtown Toronto
# 72      M4Y  Downtown Toronto
# 73      M7Y      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                        Harbourfront  43.654260 -79.360636
# 1                                         Regent Park  43.654260 -79.360636
# 2                                             Ryerson  43.657162 -79.378937
# 3                                     Garden District  43.657162 -79.378937
# 4                                      St. James Town  43.651494 -79.375418
# 5                                         The Beaches  43.676357 -79.293031
# 6                                         Berczy Park  43.644771 -79.373306
# 7                                  Central Bay Street  43.657952 -79.387383
# 8
Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
address = 'Toronto, ON'
geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# create map of Toronto using latitude and longitude values
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# # Visualise the data using Folium map

# %%
# add markers to map
for lat, lng, borough, neighborhood in zip(df_location['Latitude'], df_location['Longitude'], df_location['Borough'], df_location['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Create a dataframe for cluster analysis

# %%
df_clus=df_location.drop(['Borough','Neighbourhood','Postcode'],1)

# %%
df_clus
# Out:
#      Latitude  Longitude
# 0   43.654260 -79.360636
# 1   43.654260 -79.360636
# 2   43.657162 -79.378937
# 3   43.657162 -79.378937
# 4   43.651494 -79.375418
# 5   43.676357 -79.293031
# 6   43.644771 -79.373306
# 7   43.657952 -79.387383
# 8   43.669542 -79.422564
# 9   43.650571 -79.384568
# 10  43.650571 -79.384568
# 11  43.650571 -79.384568
# 12  43.669005 -79.442259
# 13  43.669005 -79.442259
# 14  43.640816 -79.381752
# 15  43.640816 -79.381752
# 16  43.640816 -79.381752
# 17  43.647927 -79.419750
# 18  43.647927 -79.419750
# 19  43.679557 -79.352188
# 20  43.679557 -79.352188
# 21  43.647177 -79.381576
# 22  43.647177 -79.381576
# 23  43.636847 -79.428191
# 24  43.636847 -79.428191
# 25  43.636847 -79.428191
# 26  43.668999 -79.315572
# 27  43.668999 -79.315572
# 28  43.648198 -79.379817
# 29  43.648198 -79.379817
# 30  43.659526 -79.340923
# 31  43.728020 -79.388790
# 32  43.711695 -79.416936
# 33  43.712751 -79.390197
# 34  43.696948 -79.411307
# 35  43.696948 -79.411307
# 36  43.661608 -79.464763
# 37  43.661608 -79.464763
# 38  43.715383 -79.405678
# 39  43.672710 -79.405678
# 40  43.672710 -79.405678
# 41  43.672710 -79.405678
# 42  43.648960 -79.456325
# 43  43.648960 -79.456325
# 44  43.704324 -79.388790
# 45  43.662696 -79.400049
# 46  43.662696 -79.400049
# 47  43.651571 -79.484450
# 48  43.651571 -79.484450
# 49  43.689574 -79.383160
# 50  43.689574 -79.383160
# 51  43.653206 -79.400049
# 52  43.653206 -79.400049
# 53  43.653206 -79.400049
# 54  43.686412 -79.400049
# 55  43.686412 -79.400049
# 56  43.686412 -79.400049
# 57  43.686412 -79.400049
# 58  43.686412 -79.400049
# 59  43.628947 -79.394420
# 60  43.628947 -79.394420
# 61  43.628947 -79.394420
# 62  43.628947 -79.394420
# 63  43.628947 -79.394420
# 64  43.628947 -79.394420
# 65  43.628947 -79.394420
# 66  43.679563 -79.377529
# 67  43.646435 -79.374846
# 68  43.667967 -79.367675
# 69  43.667967 -79.367675
# 70  43.648429 -79.382280
# 71  43.648429 -79.382280
# 72  43.665860 -79.383160
# 73  43.662744 -79.321558

# %%
num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(df_clus)
labels = k_means.labels_

print(labels.dtype)
# Out:
# int32

# %%
df_clus['Labels']=labels
df_clus
# Out:
#      Latitude  Longitude  Labels
# 0   43.654260 -79.360636       0
# 1   43.654260 -79.360636       0
# 2   43.657162 -79.378937       0
# 3   43.657162 -79.378937       0
# 4   43.651494 -79.375418       0
